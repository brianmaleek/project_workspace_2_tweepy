# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import tweepy
import json
import time
import config
import seaborn as sns
from datetime import datetime
from IPython.display import Image
from functools import reduce
# %matplotlib inline
plt.style.use('seaborn-notebook')
# Out:
# C:\Users\X1\anaconda3\envs\tea_facts\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
twitter_archive_master = pd.read_csv('twitter_archive_master.csv')
twitter_archive_master.head(3)
# Out:
#              tweet_id                  timestamp  \
# 0  666418789513326592  2015-11-17 00:53:15+00:00
# 1  666447344410484738  2015-11-17 02:46:43+00:00
# 2  666454714377183233  2015-11-17 03:16:00+00:00
#
#                                                 text  rating_numerator  \
# 0  This is Walter. He is an Alaskan Terrapin. Lov...              10.0
# 1  This is Scout. She is a black Downton Abbey. I...               9.0
# 2  I'll name the dogs from now on. This is Kreggo...              10.0
#
#    rating_denominator      name  \
# 0                10.0    Walter
# 1                10.0     Scout
# 2                10.0  Kreggory
#
#                                           dog_stages  retweet_count  \
# 0  https://twitter.com/dog_rates/status/666418789...           39.0
# 1  https://twitter.com/dog_rates/status/666447344...           19.0
# 2  https://twitter.com/dog_rates/status/666454714...          179.0
#
#    favorite_count                 created_at  ... img_num  \
# 0           107.0  2015-11-17 00:53:15+00:00  ...     1.0
# 1            90.0  2015-11-17 02:46:43+00:00  ...     1.0
# 2           447.0  2015-11-17 03:16:00+00:00  ...     1.0
#
#                        p1   p1_conf  p1_dog                  p2   p2_conf  \
# 0             Toy_terrier  0.149680    True            Papillon  0.148258
# 1  Curly-coated_retriever  0.322084    True     Giant_schnauzer  0.287955
# 2               Dalmatian  0.278954    True  Labrador_retriever  0.237612
#
#    p2_dog                  p3   p3_conf  p3_dog
# 0    True           Chihuahua  0.142860    True
# 1    True  Labrador_retriever  0.166331    True
# 2    True      Great_pyrenees  0.171106    True
#
# [3 rows x 21 columns]

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %% [markdown]
# 1. What is the correlation betweeen retweet_count and favorite_count
# 2. correlation betweenNumerator rating and likes?
# 3. Correlation between 'retweet_count','favorite_count', 'rating_numerator'

# %% [markdown]
# ### Visualization

# %%
# 1. What is the correlation betweeen retweet_count and favorite_count
#plots a scatter plot to display the correlation between favorite_count and retweet_count
sns.scatterplot(data=twitter_archive_master, x='favorite_count', y='retweet_count').set(title = 'correlation betweet retweet_count, and favorite-count')
sns.set(rc={'figure.figsize':(15, 10)})

# %% [markdown]
# The above scatter plot shows that there is a positive correlation between retweet_counts and favorite_counts.

# %%
# let's plot the ratings that are less than 20
plt.hist(twitter_archive_master.rating_numerator[twitter_archive_master.rating_numerator <= 17], 
         bins=np.arange(0,18,step=1), align='left');
plt.xticks(np.arange(0,18,step=1));
plt.title('Ratings Between 0 and 17 (all /10)');
plt.xlabel('Rating Numerator');
plt.ylabel('Count');

# %% [markdown]
# The bar chart above shows dogs with ratings numerator of between 10-12 have the most likes.

# %%
sns.heatmap(twitter_archive_master[['retweet_count','favorite_count', 'rating_numerator']].corr(), cmap="plasma_r", annot=True)
plt.title('Variables Correlation', size=15)
# Out:
# Text(0.5, 1.0, 'Variables Correlation')

# %% [markdown]
# strongest correlation is between retweet_count and and favorite count having a correlation coefficient of 0.8
